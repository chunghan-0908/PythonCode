# %% [markdown]
# # Kiểu dữ liệu

# %% [markdown]
# Tạo chú thích
# b -> m -> #(in đậm)
# ctrl + ?

# %%
type(10)
# Out:
# int

# %%
type(3.1)
# Out:
# float

# %%
print(type(10))
print(type(3.4))
print(type("Hello"))
print(type(False))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
a = "Hello"
b = "Python"
print(a+b)
c = a + b
print(c*3)
print(c+c+c)
# Out:
# HelloPython
# HelloPythonHelloPythonHelloPython
# HelloPythonHelloPythonHelloPython

# %%
a = True
b = False
c = a + b
print(c)
# Out:
# 1

# %%
a = True
b = True
c = a + b
print(c)
# Out:
# 2

# %%
# True -> 1, False -> 0 (được quy đổi thành số tự nhiên)

# %%
# True -> 1, False -> 0 (được quy đổi thành số tự nhiên)
a = False
b = False
c = a + b
print(c)
# Out:
# 0

# %%
a = 10
b = True
print(a+b)
# Out:
# 11

# %% [markdown]
# # Toán tử

# %% [markdown]
# ## Toán tử cộng

# %%
4 + 6
# Out:
# 10

# %%
4.5 + 5.5
# Out:
# 10.0

# %% [markdown]
# ## Toán tử trừ

# %%
5-2
# Out:
# 3

# %%
2.3 - 1.2
# Out:
# 1.0999999999999999

# %% [markdown]
# ## Toán tử nhân

# %%
4*5
# Out:
# 20

# %%
2.5 * 3.2
# Out:
# 8.0

# %% [markdown]
# ## Toán tử chia

# %%
10/2
# Out:
# 5.0

# %%
10.5/ 2.1
# Out:
# 5.0

# %% [markdown]
# ## Chia lấy dư

# %%
7 / 3
# Out:
# 2.3333333333333335

# %%
7 // 3
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %% [markdown]
# ## Lũy thừa

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 4
# Out:
# 16

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y
# Out:
# True

# %%
x + y >= z
# Out:
# True

# %%
(x ** 2 - z)**0.5 == y
# Out:
# True

# %%
x + y + (x < y) -1 == z
# Out:
# False

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 5 
a = a + 1 #Tăng giá trị của a lên 1 đơn vị 
print(a)
# Out:
# 6

# %%
a = 5
a += 1
print(a)
# Out:
# 6

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y and z > x
# Out:
# True
